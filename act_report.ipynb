# %% [markdown]
# ## Report: act_report
# * Create a **250-word-minimum written report** called "act_report.pdf" or "act_report.html" that communicates the insights and displays the visualization(s) produced from your wrangled data. This is to be framed as an external document, like a blog post or magazine article, for example.

# %% [markdown]
# ## Analyzing and Visualizing Data
# In this section, analyze and visualize your wrangled data. You must produce at least **three (3) insights and one (1) visualization.**

# %%
import pandas as pd

# %%
twitter_archive_master = pd.read_csv('twitter_archive_master.csv')
twitter_archive_master.groupby(by=['dog_category']).count().sort_values(by=['in_reply_to_user_id'])
# Out:
#               Unnamed: 0  tweet_id  expanded_urls  rating_ratio  name  date  \
# dog_category
# doggofloofer           1         1              1             1     0     1
# doggopuppo             1         1              1             1     0     1
# floofer                9         9              9             9     5     9
# doggopupper           12        12             12            12     6    12
# puppo                 29        29             28            29    20    29
# doggo                 83        83             80            83    47    83
# pupper               243       243            241           243   140   243
#
#               time  source_link  source_tag  rating_text  rating_link  \
# dog_category
# doggofloofer     1            1           1            1            1
# doggopuppo       1            1           1            1            1
# floofer          9            9           9            9            9
# doggopupper     12           12          12           12           12
# puppo           29           29          29           28           28
# doggo           83           83          83           80           80
# pupper         243          243         243          241          241
#
#               in_reply_to_status_id  in_reply_to_user_id  retweeted_status_id  \
# dog_category
# doggofloofer                      0                    0                    0
# doggopuppo                        0                    0                    0
# floofer                           0                    0                    0
# doggopupper                       1                    1                    2
# puppo                             1                    1                    5
# doggo                             3                    3                    8
# pupper                            3                    3                   21
#
#               retweeted_status_user_id  retweet_date  retweet_time
# dog_category
# doggofloofer                         0             0             0
# doggopuppo                           0             0             0
# floofer                              0             0             0
# doggopupper                          2             2             2
# puppo                                5             5             5
# doggo                                8             8             8
# pupper                              21            21            21

# %%
category_rating = twitter_archive_master.groupby(by=['dog_category']).mean().iloc[1:,:].sort_values(by=['rating_ratio'])
x = category_rating.index.values.astype('str')
y = category_rating.rating_ratio.values

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
plt.title('Rating Score')
plt.xticks(range(len(x)), x)
ax.bar(range(len(x)), y, width=0.5)
plt.xticks(rotation='45')
plt.show()

# %%
category_rating = twitter_archive_master.groupby(by=['source_tag']).count().sort_values(by=['tweet_id'])
x = category_rating.index.values.astype('str')
y = category_rating.rating_ratio.values
plt.title('people tweeting dogs', y = 1.1)
plt.pie(y, labels=x, radius=1.5, autopct='%1.1f%%', explode=[0.5, 0.5, 0.5, 0])
plt.show()

# %% [markdown]
# ### Insights:
# 1. The most common order for dogs is: pupper, doggo, puppo, doggopupper, floofer, doggopuppo, doggofluffer.
#
# 2. Among the most common dogs, the top three popular order is: pupper, floofer, and doggo, doggopuppo has the highest rating but there is only 1 rating for it, so doggopuppo is not counted.
#
# 3. Most people (94.1%) use iPhone to tweet dogs, TweetDeck is used the least (0.4%).
